# %% [markdown]
# <a href="https://colab.research.google.com/github/chsumin0316-oss/Khuda_9_ML_1/blob/main/week1/student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # KHUDA 9기 ML세션
# 2026.01.22 (목)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# dataset repository path
url = "https://raw.githubusercontent.com/gaeng02/KHUDA-9th-ML/main/week1/titanic.csv"

# %%
df = pd.read_csv(url)
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
### answer init
answer = [0] * 6

# %% [markdown]
# ## Task 1
# df의 feature중 `Fare`의 중앙값을 구하고, 해당 값을 `answer[1]`에 저장하세요.

# %%
## Input Box

median_fare = 0
median_fare = df['Fare'].median()
answer[1] = median_fare

print(median_fare)
# Out:
# 14.4542

# %%
answer[1] = median_fare

# %% [markdown]
# ## Task 2
# df의 feature중 `Pclass`에 대해 평균 생존률이 가장 높은 `Pclass`를 `answer[2]`에 저장하세요.

# %%
## Input Box

high_mean_survival_rate = 0
high_mean_survival_rate = df.groupby('Pclass')['Survived'].mean()
high_mean_survival_rate = high_mean_survival_rate.idxmax()


print(high_mean_survival_rate)
# Out:
# 1

# %%
answer[2] = high_mean_survival_rate

# %% [markdown]
# ## Task 3
# df의 feature중 `Age`에 대해서 `Age < 10`인 승객 수를 `answer[3]`에 저장하세요.

# %%
## Input Box

age_under_10 = 0
df[df['Age'] < 10]['Age']
# Out:
# 7      2.00
# 10     4.00
# 16     2.00
# 24     8.00
# 42     3.00
#        ...
# 827    0.83
# 846    4.00
# 848    9.00
# 865    4.00
# 884    7.00
# Name: Age, Length: 71, dtype: float64

# %%
age_under_10 = 71

# %%
answer[3] = age_under_10

# %% [markdown]
# ## Task 4
# 성별이 여성(`Sex`가 `female`)이면서 생존자(`Survived`가 `1`)인 승객 수를 `answer[4]`에 저장하세요.

# %%
## Input Box

female_survive_rate = 0
df[(df['Sex']=='female') & (df['Survived']==1)]
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 8           1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9           1       2                 Mrs. Nicholas (Adele Achem) Nasser
# ..        ...     ...                                                ...
# 870         1       2               Mrs. Samuel (Hannah Wizosky) Abelson
# 871         1       3                           Miss. Adele Kiamie Najib
# 875         1       1       Mrs. Thomas Jr (Lily Alexenia Wilson) Potter
# 876         1       2        Mrs. William (Imanita Parrish Hall) Shelley
# 883         1       1                        Miss. Margaret Edith Graham
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 1    female  38.0                        1                        0  71.2833
# 2    female  26.0                        0                        0   7.9250
# 3    female  35.0                        1                        0  53.1000
# 8    female  27.0                        0                        2  11.1333
# 9    female  14.0                        1                        0  30.0708
# ..      ...   ...                      ...                      ...      ...
# 870  female  28.0                        1                        0  24.0000
# 871  female  15.0                        0                        0   7.2250
# 875  female  56.0                        0                        1  83.1583
# 876  female  25.0                        0                        1  26.0000
# 883  female  19.0                        0                        0  30.0000
#
# [233 rows x 8 columns]

# %%
female_survive_rate = 233

# %%
answer[4] = female_survive_rate

# %% [markdown]
# ## Task 5
# 다음 그래프가 df의 feature중 어떤 feature의 그래프인지 시각화를 해본 후, feature 명을 `answer[5]`에 저장하세요.
#
# ![다운로드.png](data:image/png;base64,...)

# %%
## Input Box

feature_name = "feature_name"
print(df.describe())

sns.histplot(df['Fare'], bins=5)
feature_name = 'Fare'
print(feature_name)
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# max                   6.000000  512.32920
# Fare

# %%
feature_name = 'Fare'

# %%
answer[5] = feature_name

# %% [markdown]
# # 정답 확인!

# %%
print("=== 작성하신 정답 ===")
for i in range (1, 6) : print("Task " + str(i) + " :: " + str(answer[i]))
# Out:
# === 작성하신 정답 ===
# Task 1 :: 0
# Task 2 :: 0
# Task 3 :: 0
# Task 4 :: 0
# Task 5 :: feature_name

# %%
### 정답 채점 코드
import hashlib

ANSWER_URL = "https://raw.githubusercontent.com/gaeng02/KHUDA-9th-ML/main/week1/answer.csv"

def md5 (s) : return hashlib.md5(s.encode("utf-8")).hexdigest()

ans_df = pd.read_csv(ANSWER_URL)
gt = {int(r["task"]): str(r["answer"]).strip().lower()
      for _, r in ans_df.iterrows()}

wrong = []

for i in range(1, 6) :
    user_answer = "" if answer[i] is None else md5(str(answer[i]).strip().lower())
    if (user_answer != gt.get(i, "")) : wrong.append(i)

print("탈출!" if not wrong else f"틀린번호 : {wrong}")
# Out:
# 틀린번호 : [1, 2, 3, 4, 5]
